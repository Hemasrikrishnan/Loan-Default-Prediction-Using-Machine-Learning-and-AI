# %%
import pandas as pd
import numpy as np
data_reduced=pd.read_csv("final_data_v3.csv")

# %%
data_reduced.shape
# Out:
# (146231, 146)

# %%
X=data_reduced.drop(['loan_status'],axis=1)
y=data_reduced[['loan_status']]

# %%
correlation_matrix=X.corr()

# %%
# Filter the correlation matrix to show only values greater than 0.6
filtered_corr = correlation_matrix.where(correlation_matrix > 0.6, np.nan)

# Set the diagonal values to NaN
np.fill_diagonal(filtered_corr.values, np.nan)

np.fill_diagonal(filtered_corr.values, np.nan)

# Drop rows and columns where all elements are NaN
filtered_corr = filtered_corr.dropna(how='all').dropna(axis=1, how='all')

# Melt the DataFrame to show only the non-NaN values
filtered_corr_melted = filtered_corr.stack().reset_index()
filtered_corr_melted.columns = ['Variable 1', 'Variable 2', 'Correlation']

print(filtered_corr_melted)
# Out:
#               Variable 1            Variable 2  Correlation
# 0            installment       total_rec_prncp     0.765573
# 1            delinq_2yrs    num_tl_90g_dpd_24m     0.667981
# 2                pub_rec  pub_rec_bankruptcies     0.609783
# 3                pub_rec             tax_liens     0.739624
# 4              revol_bal      total_rev_hi_lim     0.813389
# 5              total_acc             num_il_tl     0.695882
# 6              total_acc         num_rev_accts     0.740337
# 7              total_acc              num_sats     0.697688
# 8        total_rec_prncp           installment     0.765573
# 9        total_rec_prncp       last_pymnt_amnt     0.659399
# 10       last_pymnt_amnt       total_rec_prncp     0.659399
# 11  last_fico_range_high   last_fico_range_low     0.841422
# 12   last_fico_range_low  last_fico_range_high     0.841422
# 13        acc_now_delinq          num_tl_30dpd     0.820706
# 14      total_rev_hi_lim             revol_bal     0.813389
# 15      total_rev_hi_lim        total_bc_limit     0.628713
# 16  acc_open_past_24mths    num_tl_op_past_12m     0.756648
# 17           avg_cur_bal       tot_hi_cred_lim     0.782737
# 18        bc_open_to_buy        total_bc_limit     0.832413
# 19               bc_util      percent_bc_gt_75     0.846216
# 20        num_actv_bc_tl           num_bc_sats     0.826593
# 21        num_actv_bc_tl         num_op_rev_tl     0.658282
# 22        num_actv_bc_tl   num_rev_tl_bal_gt_0     0.803028
# 23           num_bc_sats        num_actv_bc_tl     0.826593
# 24           num_bc_sats             num_bc_tl     0.724757
# 25           num_bc_sats         num_op_rev_tl     0.743300
# 26           num_bc_sats   num_rev_tl_bal_gt_0     0.639047
# 27           num_bc_sats        total_bc_limit     0.608193
# 28             num_bc_tl           num_bc_sats     0.724757
# 29             num_bc_tl         num_op_rev_tl     0.626133
# 30             num_bc_tl         num_rev_accts     0.835595
# 31             num_il_tl             total_acc     0.695882
# 32         num_op_rev_tl        num_actv_bc_tl     0.658282
# 33         num_op_rev_tl           num_bc_sats     0.743300
# 34         num_op_rev_tl             num_bc_tl     0.626133
# 35         num_op_rev_tl         num_rev_accts     0.779222
# 36         num_op_rev_tl   num_rev_tl_bal_gt_0     0.796046
# 37         num_op_rev_tl              num_sats     0.801201
# 38         num_rev_accts             total_acc     0.740337
# 39         num_rev_accts             num_bc_tl     0.835595
# 40         num_rev_accts         num_op_rev_tl     0.779222
# 41         num_rev_accts              num_sats     0.616300
# 42   num_rev_tl_bal_gt_0        num_actv_bc_tl     0.803028
# 43   num_rev_tl_bal_gt_0           num_bc_sats     0.639047
# 44   num_rev_tl_bal_gt_0         num_op_rev_tl     0.796046
# 45   num_rev_tl_bal_gt_0              num_sats     0.640302
# 46              num_sats             total_acc     0.697688
# 47              num_sats         num_op_rev_tl     0.801201
# 48              num_sats         num_rev_accts     0.616300
# 49              num_sats   num_rev_tl_bal_gt_0     0.640302
# 50          num_tl_30dpd        acc_now_delinq     0.820706
# 51    num_tl_90g_dpd_24m           delinq_2yrs     0.667981
# 52    num_tl_op_past_12m  acc_open_past_24mths     0.756648
# 53      percent_bc_gt_75               bc_util     0.846216
# 54  pub_rec_bankruptcies               pub_rec     0.609783
# 55             tax_liens               pub_rec     0.739624
# 56       tot_hi_cred_lim           avg_cur_bal     0.782737
# 57        total_bc_limit      total_rev_hi_lim     0.628713
# 58        total_bc_limit        bc_open_to_buy     0.832413
# 59        total_bc_limit           num_bc_sats     0.608193

# %%
col_2_drop=filtered_corr_melted['Variable 2'].unique()

# %%
col_2_drop=list(col_2_drop)

# %%
col_2_drop
# Out:
# ['total_rec_prncp',
#  'num_tl_90g_dpd_24m',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'total_rev_hi_lim',
#  'num_il_tl',
#  'num_rev_accts',
#  'num_sats',
#  'installment',
#  'last_pymnt_amnt',
#  'last_fico_range_low',
#  'last_fico_range_high',
#  'num_tl_30dpd',
#  'revol_bal',
#  'total_bc_limit',
#  'num_tl_op_past_12m',
#  'tot_hi_cred_lim',
#  'percent_bc_gt_75',
#  'num_bc_sats',
#  'num_op_rev_tl',
#  'num_rev_tl_bal_gt_0',
#  'num_actv_bc_tl',
#  'num_bc_tl',
#  'total_acc',
#  'acc_now_delinq',
#  'delinq_2yrs',
#  'acc_open_past_24mths',
#  'bc_util',
#  'pub_rec',
#  'avg_cur_bal',
#  'bc_open_to_buy']

# %%
X_mod=X.drop(col_2_drop,axis=1)

# %%
X_mod.shape
# Out:
# (146231, 114)

# %%
X_mod.columns
# Out:
# Index(['int_rate', 'annual_inc', 'dti', 'fico_range_high', 'inq_last_6mths',
#        'total_rec_int', 'total_rec_late_fee', 'collection_recovery_fee',
#        'collections_12_mths_ex_med', 'tot_coll_amt',
#        ...
#        'hardship_flag_N', 'disbursement_method_Cash',
#        'disbursement_method_DirectPay', 'debt_settlement_flag_N',
#        'debt_settlement_flag_Y', 'sector_Education',
#        'sector_Finance and Banking', 'sector_Healthcare', 'sector_IT',
#        'sector_Manufacturing'],
#       dtype='object', length=114)

# %%
col2=list(X_mod.filter(regex='Sentiment Score', axis=1).columns)
col2.append(list(X_mod.filter(regex='sector_', axis=1).columns))

# %%
col2=['Sentiment Score_2007',
 'Sentiment Score_2008',
 'Sentiment Score_2009',
 'Sentiment Score_2010',
 'Sentiment Score_2011',
 'Sentiment Score_2012',
 'Sentiment Score_2013',
 'Sentiment Score_2014',
 'Sentiment Score_2015',
 'Sentiment Score_2016',
 'Sentiment Score_2017',
 'Sentiment Score_2018','sector_Education',
  'sector_Finance and Banking',
  'sector_Healthcare',
  'sector_IT',
  'sector_Manufacturing']

# %% [markdown]
# ## Remove Sentiment Columns

# %%
X_mod=X_mod.drop(col2,axis=1)

# %%
X_mod.shape
# Out:
# (146231, 97)

# %% [markdown]
# ### Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_mod, y, test_size=0.2, random_state=42)

# Initialize the scaler
scaler = StandardScaler()

# Fit the scaler on the training data and transform both the training and testing data
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Check the shapes of the resulting sets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (116984, 97), y_train shape: (116984, 1)
# X_test shape: (29247, 97), y_test shape: (29247, 1)

# %%
y_test.value_counts()
# Out:
# loan_status
# 1              23909
# 0               5338
# Name: count, dtype: int64

# %% [markdown]
# ## Implementing Smote for Class imbalance

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
# Apply SMOTE to the training data
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Check the distribution of the target after SMOTE
print(f"SMOTE target distribution: {Counter(y_train_smote)}")
# Out:
# SMOTE target distribution: Counter({'loan_status': 1})

# %%
y_train.value_counts()
# Out:
# loan_status
# 1              95558
# 0              21426
# Name: count, dtype: int64

# %%
y_train_smote.value_counts()
# Out:
# loan_status
# 0              95558
# 1              95558
# Name: count, dtype: int64

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# %%
import warnings
warnings.filterwarnings("ignore")
models = []
models.append(('LR', LogisticRegression()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('RF', RandomForestClassifier()))
models.append(('NB',GaussianNB()))
models.append(('XGB', XGBClassifier()))

# %% [markdown]
# ## Basic model for all data (No Smote)

# %%
for name, model in models:
    #model_name, _ = model
    model.fit(X_train, y_train)
    y_pred_train = model.predict(X_train)
    y_pred = model.predict(X_test)
    accuracy_train = accuracy_score(y_train, y_pred_train)
    accuracy_test = accuracy_score(y_test, y_pred)
    print(f"{name} Train Accuracy: {accuracy_train}")
    print(f"{name} Test Accuracy: {accuracy_test}")
# Out:
# LR Train Accuracy: 0.9419322300485536
# LR Test Accuracy: 0.940780250965911
# KNN Train Accuracy: 0.8859673117691308
# KNN Test Accuracy: 0.8593360002735323
# CART Train Accuracy: 1.0
# CART Test Accuracy: 0.8939720313194516
# RF Train Accuracy: 0.9999914518224714
# RF Test Accuracy: 0.9433446165418675
# NB Train Accuracy: 0.9162278602202011
# NB Test Accuracy: 0.9141450405169761
# XGB Train Accuracy: 0.9486938384736374
# XGB Test Accuracy: 0.9422846787704722

# %% [markdown]
# ## Basic Model for SMOTE Data

# %%
for name, model in models:
    #model_name, _ = model
    model.fit(X_train_smote, y_train_smote)
    y_pred_train = model.predict(X_train_smote)
    y_pred = model.predict(X_test)
    accuracy_train = accuracy_score(y_train_smote, y_pred_train)
    accuracy_test = accuracy_score(y_test, y_pred)
    print(f"{name} Train Accuracy: {accuracy_train}")
    print(f"{name} Test Accuracy: {accuracy_test}")
# Out:
# LR Train Accuracy: 0.8994694321773163
# LR Test Accuracy: 0.9354805621089343
# KNN Train Accuracy: 0.902629816446556
# KNN Test Accuracy: 0.7149793141176873
# CART Train Accuracy: 1.0
# CART Test Accuracy: 0.8859370191814545
# RF Train Accuracy: 1.0
# RF Test Accuracy: 0.9426607857216125
# NB Train Accuracy: 0.8976433161012161
# NB Test Accuracy: 0.9108968441207645
# XGB Train Accuracy: 0.9670828188116118
# XGB Test Accuracy: 0.943139467295791

# %% [markdown]
# ## Feature Importance for Normal Data

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix
import numpy as np

# Setting a random seed for reproducibility
random_seed = 42

# List of models to evaluate
models = []
models.append(('LR', LogisticRegression()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('RF', RandomForestClassifier()))
models.append(('NB', GaussianNB()))
models.append(('XGB', XGBClassifier()))

# Function to print top 20 feature importances
def print_feature_importance(model, X_train, name, top_n=20):
    if hasattr(model, "feature_importances_"):
        importances = model.feature_importances_
        feature_names = X_mod.columns
        sorted_indices = np.argsort(importances)[::-1]
        print(f"{name} Top {top_n} Feature Importances:")
        for idx in sorted_indices[:top_n]:
            print(f"{feature_names[idx]}: {importances[idx]}")
        print()
    elif hasattr(model, "coef_"):
        importances = model.coef_[0]
        feature_names = X_mod.columns
        sorted_indices = np.argsort(importances)[::-1]
        print(f"{name} Top {top_n} Feature Importances:")
        for idx in sorted_indices[:top_n]:
            print(f"{feature_names[idx]}: {importances[idx]}")
        print()
    else:
        print(f"{name} does not support feature importance.\n")

for name, model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    # Calculate classification metrics
    report = classification_report(y_test, y_pred)
    
    # Calculate confusion matrix
    conf_matrix = confusion_matrix(y_test, y_pred)
    
    # Calculate ROC-AUC score if the model supports predict_proba
    if hasattr(model, "predict_proba"):
        y_pred_proba = model.predict_proba(X_test)[:, 1]
        roc_auc = roc_auc_score(y_test, y_pred_proba)
    else:
        roc_auc = "N/A"
    
    print(f"{name} Classification Report:")
    print(report)
    print(f"ROC-AUC Score: {roc_auc}")
    print(f"Confusion Matrix:\n{conf_matrix}")
    print()
    
    # Print top 20 feature importances
    print_feature_importance(model, X_train, name, top_n=20)
# Out:
# LR Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.68      0.81      5338
#            1       0.93      1.00      0.97     23909
#
#     accuracy                           0.94     29247
#    macro avg       0.96      0.84      0.89     29247
# weighted avg       0.94      0.94      0.94     29247
#
# ROC-AUC Score: 0.9147847352584431
# Confusion Matrix:
# [[ 3626  1712]
#  [   20 23889]]
#
# LR Top 20 Feature Importances:
# debt_settlement_flag_N: 0.8556169954742144
# term_36 months: 0.17675968427547895
# total_rec_int: 0.16321437567816205
# mort_acc: 0.13584388881363268
# mths_since_recent_bc: 0.08693596734952116
# fico_range_high: 0.06816192727075535
# sub_grade_A1: 0.06624706903751133
# grade_A: 0.06285403682934755
# home_ownership_MORTGAGE: 0.05763263753758867
# sub_grade_A3: 0.036102605680432505
# total_il_high_credit_limit: 0.03267837278547872
# verification_status_Not Verified: 0.030921211551812988
# mths_since_recent_inq: 0.030776007858181298
# mo_sin_old_rev_tl_op: 0.030193268201594903
# purpose_vacation: 0.029665723723010608
# mo_sin_rcnt_tl: 0.029414686849629095
# sub_grade_A2: 0.026310640529788064
# annual_inc: 0.022419466072252696
# application_type_Individual: 0.020863170359352513
# initial_list_status_w: 0.020546264862680495
#
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.33      0.46      5338
#            1       0.87      0.98      0.92     23909
#
#     accuracy                           0.86     29247
#    macro avg       0.82      0.65      0.69     29247
# weighted avg       0.85      0.86      0.84     29247
#
# ROC-AUC Score: 0.7428772407166858
# Confusion Matrix:
# [[ 1761  3577]
#  [  537 23372]]
#
# KNN does not support feature importance.
#
# CART Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.73      0.71      5338
#            1       0.94      0.93      0.93     23909
#
#     accuracy                           0.89     29247
#    macro avg       0.82      0.83      0.82     29247
# weighted avg       0.90      0.89      0.89     29247
#
# ROC-AUC Score: 0.8309489086108168
# Confusion Matrix:
# [[ 3917  1421]
#  [ 1719 22190]]
#
# CART Top 20 Feature Importances:
# collection_recovery_fee: 0.6309627132325695
# total_rec_int: 0.03284260742967887
# dti: 0.028738542724321848
# total_il_high_credit_limit: 0.025233384337130262
# mo_sin_old_il_acct: 0.02506957147749488
# mo_sin_old_rev_tl_op: 0.0246672000707159
# int_rate: 0.024641592641197956
# annual_inc: 0.02335611052828703
# debt_settlement_flag_N: 0.020147843175299673
# mths_since_recent_bc: 0.01780270595620288
# mths_since_recent_inq: 0.016794928198235342
# fico_range_high: 0.01633140306220891
# mo_sin_rcnt_rev_tl_op: 0.01401089125469002
# mo_sin_rcnt_tl: 0.012896454774724649
# mort_acc: 0.007978957720339757
# tot_coll_amt: 0.007379098740456052
# total_rec_late_fee: 0.006780603567431548
# inq_last_6mths: 0.004955927538557141
# num_accts_ever_120_pd: 0.004858245156153508
# verification_status_Verified: 0.002514633089276742
#
# RF Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.69      0.82      5338
#            1       0.94      1.00      0.97     23909
#
#     accuracy                           0.94     29247
#    macro avg       0.97      0.85      0.89     29247
# weighted avg       0.95      0.94      0.94     29247
#
# ROC-AUC Score: 0.9105408353244469
# Confusion Matrix:
# [[ 3688  1650]
#  [    9 23900]]
#
# RF Top 20 Feature Importances:
# collection_recovery_fee: 0.44988110943120724
# debt_settlement_flag_N: 0.04091946699056832
# int_rate: 0.03647741099692056
# debt_settlement_flag_Y: 0.03601681379055684
# total_rec_int: 0.030634049080932438
# dti: 0.029549800903906364
# mo_sin_old_rev_tl_op: 0.027616653142702986
# mo_sin_old_il_acct: 0.027099057200174456
# total_il_high_credit_limit: 0.0263051769491022
# annual_inc: 0.026132170708926122
# total_rec_late_fee: 0.022447092368716427
# mths_since_recent_bc: 0.02214310328553777
# fico_range_high: 0.02155121856124204
# mo_sin_rcnt_rev_tl_op: 0.019509480142968057
# mths_since_recent_inq: 0.018719224866359435
# mo_sin_rcnt_tl: 0.01802799468313724
# mort_acc: 0.012159349831362782
# inq_last_6mths: 0.008740283998248537
# tot_coll_amt: 0.008402358438062753
# term_60 months: 0.008193135601833669
#
# NB Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.73      0.76      5338
#            1       0.94      0.95      0.95     23909
#
#     accuracy                           0.91     29247
#    macro avg       0.86      0.84      0.85     29247
# weighted avg       0.91      0.91      0.91     29247
#
# ROC-AUC Score: 0.8783352682279869
# Confusion Matrix:
# [[ 3921  1417]
#  [ 1094 22815]]
#
# NB does not support feature importance.
#
# XGB Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.69      0.81      5338
#            1       0.94      1.00      0.97     23909
#
#     accuracy                           0.94     29247
#    macro avg       0.96      0.85      0.89     29247
# weighted avg       0.95      0.94      0.94     29247
#
# ROC-AUC Score: 0.9152713162235083
# Confusion Matrix:
# [[ 3701  1637]
#  [   51 23858]]
#
# XGB Top 20 Feature Importances:
# collection_recovery_fee: 0.8474580645561218
# debt_settlement_flag_N: 0.03373313695192337
# grade_A: 0.012235885486006737
# term_36 months: 0.00685247452929616
# int_rate: 0.0047836629673838615
# total_rec_late_fee: 0.004577073734253645
# sub_grade_F5: 0.003203196218237281
# home_ownership_RENT: 0.003032171167433262
# application_type_Individual: 0.0021647296380251646
# home_ownership_MORTGAGE: 0.0020838396158069372
# purpose_small_business: 0.0019318179693073034
# grade_C: 0.0019118478521704674
# mort_acc: 0.0017690464155748487
# purpose_car: 0.0017658231081441045
# sub_grade_D2: 0.0016758338315412402
# sub_grade_D5: 0.0016328302444890141
# sub_grade_F3: 0.001590232946909964
# total_rec_int: 0.0015538034494966269
# sub_grade_D3: 0.0015486845513805747
# sub_grade_C3: 0.0014835820766165853

# %% [markdown]
# ## Feature Importance for SMOTE Data

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix
import numpy as np

# Setting a random seed for reproducibility
random_seed = 42

# List of models to evaluate
models = []
models.append(('LR', LogisticRegression()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('RF', RandomForestClassifier()))
models.append(('NB', GaussianNB()))
models.append(('XGB', XGBClassifier()))

# Function to print top 20 feature importances
def print_feature_importance(model, X_train_smote, name, top_n=20):
    if hasattr(model, "feature_importances_"):
        importances = model.feature_importances_
        feature_names = X_mod.columns
        sorted_indices = np.argsort(importances)[::-1]
        print(f"{name} Top {top_n} Feature Importances:")
        for idx in sorted_indices[:top_n]:
            print(f"{feature_names[idx]}: {importances[idx]}")
        print()
    elif hasattr(model, "coef_"):
        importances = model.coef_[0]
        feature_names = X_mod.columns
        sorted_indices = np.argsort(importances)[::-1]
        print(f"{name} Top {top_n} Feature Importances:")
        for idx in sorted_indices[:top_n]:
            print(f"{feature_names[idx]}: {importances[idx]}")
        print()
    else:
        print(f"{name} does not support feature importance.\n")

for name, model in models:
    model.fit(X_train_smote, y_train_smote)
    y_pred = model.predict(X_test)
    
    # Calculate classification metrics
    report = classification_report(y_test, y_pred)
    
    # Calculate confusion matrix
    conf_matrix = confusion_matrix(y_test, y_pred)
    
    # Calculate ROC-AUC score if the model supports predict_proba
    if hasattr(model, "predict_proba"):
        y_pred_proba = model.predict_proba(X_test)[:, 1]
        roc_auc = roc_auc_score(y_test, y_pred_proba)
    else:
        roc_auc = "N/A"
    
    print(f"{name} Classification Report:")
    print(report)
    print(f"ROC-AUC Score: {roc_auc}")
    print(f"Confusion Matrix:\n{conf_matrix}")
    print()
    
    # Print top 20 feature importances
    print_feature_importance(model, X_train_smote, name, top_n=20)
# Out:
# LR Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.71      0.80      5338
#            1       0.94      0.99      0.96     23909
#
#     accuracy                           0.94     29247
#    macro avg       0.93      0.85      0.88     29247
# weighted avg       0.93      0.94      0.93     29247
#
# ROC-AUC Score: 0.9141399070576722
# Confusion Matrix:
# [[ 3786  1552]
#  [  335 23574]]
#
# LR Top 20 Feature Importances:
# debt_settlement_flag_N: 1.0885574810919374
# term_36 months: 0.2043286855305284
# total_rec_int: 0.1844530445278727
# mths_since_recent_bc: 0.153976635070817
# mort_acc: 0.14415549089453092
# fico_range_high: 0.09890245101418421
# mths_since_recent_inq: 0.0774565443165469
# total_il_high_credit_limit: 0.0708008561931619
# mo_sin_old_rev_tl_op: 0.059671267617766366
# annual_inc: 0.057611157411051224
# num_accts_ever_120_pd: 0.05523768068933652
# purpose_vacation: 0.04803453131321315
# home_ownership_OWN: 0.047011757060760294
# sub_grade_A3: 0.03773496681493137
# mo_sin_rcnt_tl: 0.036546329269369605
# chargeoff_within_12_mths: 0.035962227204264646
# verification_status_Not Verified: 0.03586573761610926
# home_ownership_MORTGAGE: 0.031124859557289785
# sub_grade_A2: 0.029545421150792135
# tot_coll_amt: 0.02885152600077842
#
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.35      0.64      0.45      5338
#            1       0.90      0.73      0.81     23909
#
#     accuracy                           0.71     29247
#    macro avg       0.62      0.69      0.63     29247
# weighted avg       0.80      0.71      0.74     29247
#
# ROC-AUC Score: 0.7455926618915881
# Confusion Matrix:
# [[ 3423  1915]
#  [ 6421 17488]]
#
# KNN does not support feature importance.
#
# CART Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.66      0.74      0.70      5338
#            1       0.94      0.92      0.93     23909
#
#     accuracy                           0.88     29247
#    macro avg       0.80      0.83      0.81     29247
# weighted avg       0.89      0.88      0.89     29247
#
# ROC-AUC Score: 0.8273841088261458
# Confusion Matrix:
# [[ 3939  1399]
#  [ 1988 21921]]
#
# CART Top 20 Feature Importances:
# collection_recovery_fee: 0.6766326279959293
# mort_acc: 0.03745083498022697
# inq_last_6mths: 0.037327351348803335
# term_36 months: 0.02659506918292954
# total_rec_late_fee: 0.01826814895540445
# int_rate: 0.017685006784985254
# total_rec_int: 0.015676745596135695
# mo_sin_old_rev_tl_op: 0.014217009315178528
# dti: 0.013510091968840052
# mo_sin_old_il_acct: 0.012929368342356742
# total_il_high_credit_limit: 0.012753146212958038
# annual_inc: 0.011927057998691289
# mths_since_recent_inq: 0.011274112608759379
# fico_range_high: 0.010894361273995224
# mths_since_recent_bc: 0.009925315217370988
# mo_sin_rcnt_tl: 0.008558647160383267
# mo_sin_rcnt_rev_tl_op: 0.0077881212297134525
# tot_coll_amt: 0.005246053375157657
# debt_settlement_flag_Y: 0.00464848679840665
# num_accts_ever_120_pd: 0.0046363478788527986
#
# RF Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.69      0.82      5338
#            1       0.94      1.00      0.97     23909
#
#     accuracy                           0.94     29247
#    macro avg       0.96      0.85      0.89     29247
# weighted avg       0.95      0.94      0.94     29247
#
# ROC-AUC Score: 0.9121213527543967
# Confusion Matrix:
# [[ 3709  1629]
#  [   40 23869]]
#
# RF Top 20 Feature Importances:
# collection_recovery_fee: 0.42714757171912443
# int_rate: 0.04326067397739881
# inq_last_6mths: 0.03751283906060628
# total_rec_late_fee: 0.0322997052906094
# mort_acc: 0.024638843299283508
# debt_settlement_flag_N: 0.024221170308129272
# fico_range_high: 0.023919162777960197
# term_60 months: 0.022020282112426393
# mths_since_recent_inq: 0.021601163665762185
# debt_settlement_flag_Y: 0.02143550883827129
# total_rec_int: 0.020793193943437954
# dti: 0.01995485570767097
# total_il_high_credit_limit: 0.018757385911738127
# mo_sin_rcnt_tl: 0.01828454420039178
# num_accts_ever_120_pd: 0.01780262822458977
# mo_sin_old_rev_tl_op: 0.017530846840233497
# term_36 months: 0.017451244223928204
# annual_inc: 0.017363763313603443
# mths_since_recent_bc: 0.016834140900576344
# mo_sin_rcnt_rev_tl_op: 0.016701635242069055
#
# NB Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.75      5338
#            1       0.94      0.95      0.95     23909
#
#     accuracy                           0.91     29247
#    macro avg       0.85      0.84      0.85     29247
# weighted avg       0.91      0.91      0.91     29247
#
# ROC-AUC Score: 0.8842385839426345
# Confusion Matrix:
# [[ 3943  1395]
#  [ 1211 22698]]
#
# NB does not support feature importance.
#
# XGB Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.70      0.82      5338
#            1       0.94      1.00      0.97     23909
#
#     accuracy                           0.94     29247
#    macro avg       0.96      0.85      0.89     29247
# weighted avg       0.95      0.94      0.94     29247
#
# ROC-AUC Score: 0.9159694680973213
# Confusion Matrix:
# [[ 3717  1621]
#  [   42 23867]]
#
# XGB Top 20 Feature Importances:
# collection_recovery_fee: 0.821717381477356
# term_60 months: 0.04126815125346184
# inq_last_6mths: 0.016886424273252487
# mort_acc: 0.01149471290409565
# home_ownership_RENT: 0.009395075030624866
# num_accts_ever_120_pd: 0.007854034192860126
# verification_status_Not Verified: 0.007207956630736589
# term_36 months: 0.006942507810890675
# total_rec_late_fee: 0.006145510356873274
# debt_settlement_flag_N: 0.00603698194026947
# initial_list_status_w: 0.005946678575128317
# grade_A: 0.004699901212006807
# purpose_debt_consolidation: 0.003971128258854151
# mo_sin_rcnt_tl: 0.003646036610007286
# int_rate: 0.0023090983740985394
# mths_since_recent_inq: 0.002290812088176608
# fico_range_high: 0.0022729523479938507
# verification_status_Source Verified: 0.0022146767005324364
# tot_coll_amt: 0.002068602479994297
# initial_list_status_f: 0.0017327660461887717

# %% [markdown]
# ## Hyperparameter Tuning - Normal

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix
import numpy as np
warnings.filterwarnings("ignore")

# List of models and their hyperparameters to tune
models = []
models.append(('LR', LogisticRegression(), {'C': [0.01, 0.1, 1, 10, 100], 'solver': ['liblinear', 'lbfgs']}))
models.append(('KNN', KNeighborsClassifier(), {'n_neighbors': np.arange(5, 35, 5), 'weights': ['uniform', 'distance']}))
models.append(('CART', DecisionTreeClassifier(), {'max_depth': np.arange(5, 25, 5), 'min_samples_split': np.arange(5, 25, 5)}))
models.append(('RF', RandomForestClassifier(), {'n_estimators': np.arange(5, 25, 5), 'max_features': ['auto', 'sqrt', 'log2']}))
models.append(('NB', GaussianNB(), {}))  # GaussianNB doesn't have hyperparameters to tune
models.append(('XGB', XGBClassifier(), {'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]}))


# Iterate over each model, perform hyperparameter tuning, and evaluate
for name, model, params in models:
    if params:
        grid_search = GridSearchCV(model, param_grid=params, cv=5, scoring='roc_auc')
        grid_search.fit(X_train, y_train)
        best_model = grid_search.best_estimator_
        best_params = grid_search.best_params_
    else:
        # If there are no hyperparameters to tune
        best_model = model
        best_model.fit(X_train, y_train)
        best_params = "N/A"
    
    # Perform cross-validation
    cv_scores = cross_val_score(best_model, X_train, y_train, cv=5, scoring='roc_auc')
    mean_cv_score = np.mean(cv_scores)
    std_cv_score = np.std(cv_scores)
    
    # Fit the best model on the full training data
    best_model.fit(X_train, y_train)
    y_pred = best_model.predict(X_test)
    
    # Calculate classification metrics
    report = classification_report(y_test, y_pred)
    
    # Calculate confusion matrix
    conf_matrix = confusion_matrix(y_test, y_pred)
    
    # Calculate ROC-AUC score if the model supports predict_proba
    if hasattr(best_model, "predict_proba"):
        y_pred_proba = best_model.predict_proba(X_test)[:, 1]
        roc_auc = roc_auc_score(y_test, y_pred_proba)
    else:
        roc_auc = "N/A"
    
    print(f"{name} Classification Report:")
    print(report)
    print(f"Cross-Validation ROC-AUC Score: {mean_cv_score} ± {std_cv_score}")
    print(f"Test ROC-AUC Score: {roc_auc}")
    print(f"Confusion Matrix:\n{conf_matrix}")
    print(f"Model Params{best_params}")
    print()
# Out:
# LR Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.69      0.81      5338
#            1       0.93      1.00      0.97     23909
#
#     accuracy                           0.94     29247
#    macro avg       0.96      0.84      0.89     29247
# weighted avg       0.95      0.94      0.94     29247
#
# Cross-Validation ROC-AUC Score: 0.9159145247282302 ± 0.0013988666061179578
# Test ROC-AUC Score: 0.9153402009596114
# Confusion Matrix:
# [[ 3670  1668]
#  [   20 23889]]
# Model Params{'C': 100, 'solver': 'liblinear'}
#
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.25      0.40      5338
#            1       0.86      1.00      0.92     23909
#
#     accuracy                           0.86     29247
#    macro avg       0.89      0.62      0.66     29247
# weighted avg       0.87      0.86      0.82     29247
#
# Cross-Validation ROC-AUC Score: 0.797083840589295 ± 0.003533152503781959
# Test ROC-AUC Score: 0.7981496665865944
# Confusion Matrix:
# [[ 1340  3998]
#  [  100 23809]]
# Model Params{'n_neighbors': 30, 'weights': 'distance'}
#
# CART Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.70      0.82      5338
#            1       0.94      1.00      0.97     23909
#
#     accuracy                           0.94     29247
#    macro avg       0.96      0.85      0.89     29247
# weighted avg       0.95      0.94      0.94     29247
#
# Cross-Validation ROC-AUC Score: 0.9121730276985556 ± 0.0016197756896014956
# Test ROC-AUC Score: 0.9123883276293603
# Confusion Matrix:
# [[ 3717  1621]
#  [   44 23865]]
# Model Params{'max_depth': 10, 'min_samples_split': 20}
#
# RF Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.70      0.82      5338
#            1       0.94      1.00      0.97     23909
#
#     accuracy                           0.94     29247
#    macro avg       0.96      0.85      0.89     29247
# weighted avg       0.95      0.94      0.94     29247
#
# Cross-Validation ROC-AUC Score: 0.900917165825577 ± 0.0025205514336138495
# Test ROC-AUC Score: 0.9015204608155742
# Confusion Matrix:
# [[ 3712  1626]
#  [   47 23862]]
# Model Params{'max_features': 'sqrt', 'n_estimators': 20}
#
# NB Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.73      0.76      5338
#            1       0.94      0.95      0.95     23909
#
#     accuracy                           0.91     29247
#    macro avg       0.86      0.84      0.85     29247
# weighted avg       0.91      0.91      0.91     29247
#
# Cross-Validation ROC-AUC Score: 0.8852324067480397 ± 0.00688061173384546
# Test ROC-AUC Score: 0.8783352682279869
# Confusion Matrix:
# [[ 3921  1417]
#  [ 1094 22815]]
# Model ParamsN/A
#
# XGB Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.69      0.81      5338
#            1       0.94      1.00      0.97     23909
#
#     accuracy                           0.94     29247
#    macro avg       0.96      0.84      0.89     29247
# weighted avg       0.95      0.94      0.94     29247
#
# Cross-Validation ROC-AUC Score: 0.9211550782678488 ± 0.0022023316849567325
# Test ROC-AUC Score: 0.9210251995040329
# Confusion Matrix:
# [[ 3685  1653]
#  [   25 23884]]
# Model Params{'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}

# %% [markdown]
# ## Hyperparameter Tuning - Smote

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix
import numpy as np
warnings.filterwarnings("ignore")

# List of models and their hyperparameters to tune
models = []
models.append(('LR', LogisticRegression(), {'C': [0.01, 0.1, 1, 10, 100], 'solver': ['liblinear', 'lbfgs']}))
models.append(('KNN', KNeighborsClassifier(), {'n_neighbors': np.arange(5, 35, 5), 'weights': ['uniform', 'distance']}))
models.append(('CART', DecisionTreeClassifier(), {'max_depth': np.arange(5, 25, 5), 'min_samples_split': np.arange(5, 25, 5)}))
models.append(('RF', RandomForestClassifier(), {'n_estimators': np.arange(5, 25, 5), 'max_features': ['auto', 'sqrt', 'log2']}))
models.append(('NB', GaussianNB(), {}))  # GaussianNB doesn't have hyperparameters to tune
models.append(('XGB', XGBClassifier(), {'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]}))


# Iterate over each model, perform hyperparameter tuning, and evaluate
for name, model, params in models:
    if params:
        grid_search = GridSearchCV(model, param_grid=params, cv=5, scoring='roc_auc')
        grid_search.fit(X_train_smote, y_train_smote)
        best_model = grid_search.best_estimator_
        best_params = grid_search.best_params_
    else:
        # If there are no hyperparameters to tune
        best_model = model
        best_model.fit(X_train_smote, y_train_smote)
        best_params = "N/A"
    
    # Perform cross-validation
    cv_scores = cross_val_score(best_model, X_train_smote, y_train_smote, cv=5, scoring='roc_auc')
    mean_cv_score = np.mean(cv_scores)
    std_cv_score = np.std(cv_scores)
    
    # Fit the best model on the full training data
    best_model.fit(X_train_smote, y_train_smote)
    y_pred = best_model.predict(X_test)
    
    # Calculate classification metrics
    report = classification_report(y_test, y_pred)
    
    # Calculate confusion matrix
    conf_matrix = confusion_matrix(y_test, y_pred)
    
    # Calculate ROC-AUC score if the model supports predict_proba
    if hasattr(best_model, "predict_proba"):
        y_pred_proba = best_model.predict_proba(X_test)[:, 1]
        roc_auc = roc_auc_score(y_test, y_pred_proba)
    else:
        roc_auc = "N/A"
    
    print(f"{name} Classification Report:")
    print(report)
    print(f"Cross-Validation ROC-AUC Score: {mean_cv_score} ± {std_cv_score}")
    print(f"Test ROC-AUC Score: {roc_auc}")
    print(f"Confusion Matrix:\n{conf_matrix}")
    print(f"Model Params{best_params}")
    print()
# Out:
# LR Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.71      0.80      5338
#            1       0.94      0.99      0.96     23909
#
#     accuracy                           0.94     29247
#    macro avg       0.93      0.85      0.88     29247
# weighted avg       0.94      0.94      0.93     29247
#
# Cross-Validation ROC-AUC Score: 0.9498457436256658 ± 0.017695987890047612
# Test ROC-AUC Score: 0.9143995245115814
# Confusion Matrix:
# [[ 3784  1554]
#  [  301 23608]]
# Model Params{'C': 100, 'solver': 'lbfgs'}
#
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.35      0.67      0.46      5338
#            1       0.91      0.72      0.80     23909
#
#     accuracy                           0.71     29247
#    macro avg       0.63      0.69      0.63     29247
# weighted avg       0.81      0.71      0.74     29247
#
# Cross-Validation ROC-AUC Score: 0.9594500003621974 ± 0.007488783313168847
# Test ROC-AUC Score: 0.7704315621860902
# Confusion Matrix:
# [[ 3586  1752]
#  [ 6741 17168]]
# Model Params{'n_neighbors': 10, 'weights': 'distance'}
#
# CART Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.70      0.80      5338
#            1       0.94      0.99      0.96     23909
#
#     accuracy                           0.93     29247
#    macro avg       0.93      0.84      0.88     29247
# weighted avg       0.93      0.93      0.93     29247
#
# Cross-Validation ROC-AUC Score: 0.9604749659154779 ± 0.037979035888279576
# Test ROC-AUC Score: 0.8966581810032453
# Confusion Matrix:
# [[ 3760  1578]
#  [  352 23557]]
# Model Params{'max_depth': 15, 'min_samples_split': 20}
#
# RF Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.70      0.81      5338
#            1       0.94      0.99      0.96     23909
#
#     accuracy                           0.94     29247
#    macro avg       0.94      0.85      0.89     29247
# weighted avg       0.94      0.94      0.93     29247
#
# Cross-Validation ROC-AUC Score: 0.9874539249086013 ± 0.01834626975494968
# Test ROC-AUC Score: 0.9008021289226709
# Confusion Matrix:
# [[ 3758  1580]
#  [  221 23688]]
# Model Params{'max_features': 'log2', 'n_estimators': 20}
#
# NB Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.75      5338
#            1       0.94      0.95      0.95     23909
#
#     accuracy                           0.91     29247
#    macro avg       0.85      0.84      0.85     29247
# weighted avg       0.91      0.91      0.91     29247
#
# Cross-Validation ROC-AUC Score: 0.9317126288434731 ± 0.022237899397689897
# Test ROC-AUC Score: 0.8842385839426345
# Confusion Matrix:
# [[ 3943  1395]
#  [ 1211 22698]]
# Model ParamsN/A
#
# XGB Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.69      0.82      5338
#            1       0.94      1.00      0.97     23909
#
#     accuracy                           0.94     29247
#    macro avg       0.96      0.85      0.89     29247
# weighted avg       0.95      0.94      0.94     29247
#
# Cross-Validation ROC-AUC Score: 0.9804933163878008 ± 0.03359852137509477
# Test ROC-AUC Score: 0.9182714633249173
# Confusion Matrix:
# [[ 3699  1639]
#  [   26 23883]]
# Model Params{'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}

# %% [markdown]
# ## Deep Learning

# %%
import tensorflow as tf
from tensorflow import keras
# Out:
# WARNING:tensorflow:From C:\Users\hemak\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = keras.models.Sequential([
keras.layers.Flatten(input_shape=[97]),
keras.layers.Dense(1000, activation="relu"),
keras.layers.Dense(450, activation="relu"),
keras.layers.Dense(100, activation="relu"),
keras.layers.Dense(1, activation="softmax")
])
# Out:
# WARNING:tensorflow:From C:\Users\hemak\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
train_data = scaler.fit_transform(X_train_smote)
val_data = scaler.transform(X_test)#train_data

# %%
train_labels_mc = y_train_smote
val_labels_mc = y_test

# %%
# Since it is binary class classification categorical crossentropy and accuracy as metric is utilized to compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss="binary_crossentropy",
optimizer=opt,
metrics=["accuracy"])

# %%
history = model.fit(train_data, train_labels_mc, epochs=100, validation_data=(val_data, val_labels_mc), verbose=1)# Turn verbose=1 to printing epochs
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\hemak\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\hemak\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 5973/5973 [==============================] - 58s 9ms/step - loss: 0.4666 - accuracy: 0.5000 - val_loss: 0.4911 - val_accuracy: 0.8175
# Epoch 2/100
# 5973/5973 [==============================] - 56s 9ms/step - loss: 0.5177 - accuracy: 0.5000 - val_loss: 0.4374 - val_accuracy: 0.8175
# Epoch 3/100
# 5973/5973 [==============================] - 56s 9ms/step - loss: 0.5213 - accuracy: 0.5000 - val_loss: 0.4730 - val_accuracy: 0.8175
# Epoch 4/100
# 5973/5973 [==============================] - 57s 9ms/step - loss: 0.5170 - accuracy: 0.5000 - val_loss: 0.5336 - val_accuracy: 0.8175
# Epoch 5/100
# 5973/5973 [==============================] - 55s 9ms/step - loss: 0.5412 - accuracy: 0.5000 - val_loss: 0.4918 - val_accuracy: 0.8175
# Epoch 6/100
# 5973/5973 [==============================] - 56s 9ms/step - loss: 0.5251 - accuracy: 0.5000 - val_loss: 0.4678 - val_accuracy: 0.8175
# Epoch 7/100
# 5973/5973 [==============================] - 55s 9ms/step - loss: 0.5093 - accuracy: 0.5000 - val_loss: 0.4689 - val_accuracy: 0.8175
# Epoch 8/100
# 5973/5973 [==============================] - 62s 10ms/step - loss: 0.5617 - accuracy: 0.5000 - val_loss: 0.4764 - val_accuracy: 0.8175
# Epoch 9/100
# 5973/5973 [==============================] - 58s 10ms/step - loss: 0.5265 - accuracy: 0.5000 - val_loss: 0.4874 - val_accuracy: 0.8175
# Epoch 10/100
# 5973/5973 [==============================] - 57s 9ms/step - loss: 0.5130 - accuracy: 0.5000 - val_loss: 0.4639 - val_accuracy: 0.8175
# Epoch 11/100
# 5973/5973 [==============================] - 58s 10ms/step - loss: 0.5313 - accuracy: 0.5000 - val_loss: 0.4106 - val_accuracy: 0.8175
# Epoch 12/100
# 5973/5973 [==============================] - 55s 9ms/step - loss: 0.4756 - accuracy: 0.5000 - val_loss: 0.4226 - val_accuracy: 0.8175
# Epoch 13/100
# 5973/5973 [==============================] - 77s 13ms/step - loss: 0.5997 - accuracy: 0.5000 - val_loss: 0.5657 - val_accuracy: 0.8175
# Epoch 19/100
# 5973/5973 [==============================] - 81s 14ms/step - loss: 0.4868 - accuracy: 0.5000 - val_loss: 0.4287 - val_accuracy: 0.8175
# Epoch 20/100
# 5973/5973 [==============================] - 79s 13ms/step - loss: 0.4849 - accuracy: 0.5000 - val_loss: 0.4223 - val_accuracy: 0.8175
# Epoch 21/100
# 5973/5973 [==============================] - 82s 14ms/step - loss: 0.4624 - accuracy: 0.5000 - val_loss: 0.4121 - val_accuracy: 0.8175
# Epoch 22/100
# 5973/5973 [==============================] - 78s 13ms/step - loss: 0.4959 - accuracy: 0.5000 - val_loss: 0.3815 - val_accuracy: 0.8175
# Epoch 23/100
# 5973/5973 [==============================] - 61s 10ms/step - loss: 0.4614 - accuracy: 0.5000 - val_loss: 0.4086 - val_accuracy: 0.8175
# Epoch 29/100
# 5973/5973 [==============================] - 69s 11ms/step - loss: 0.4786 - accuracy: 0.5000 - val_loss: 0.4025 - val_accuracy: 0.8175
# Epoch 30/100
# 5973/5973 [==============================] - 75s 13ms/step - loss: 0.4542 - accuracy: 0.5000 - val_loss: 0.5370 - val_accuracy: 0.8175
# Epoch 31/100
# 5973/5973 [==============================] - 84s 14ms/step - loss: 0.4626 - accuracy: 0.5000 - val_loss: 0.4408 - val_accuracy: 0.8175
# Epoch 32/100
# 5973/5973 [==============================] - 77s 13ms/step - loss: 0.4605 - accuracy: 0.5000 - val_loss: 0.4229 - val_accuracy: 0.8175
# Epoch 33/100
# 5973/5973 [==============================] - 74s 12ms/step - loss: 0.4587 - accuracy: 0.5000 - val_loss: 0.4105 - val_accuracy: 0.8175
# Epoch 34/100
# 5973/5973 [==============================] - 75s 13ms/step - loss: 0.4790 - accuracy: 0.5000 - val_loss: 0.4221 - val_accuracy: 0.8175
# Epoch 35/100
# 5973/5973 [==============================] - 77s 13ms/step - loss: 0.4586 - accuracy: 0.5000 - val_loss: 0.4343 - val_accuracy: 0.8175
# Epoch 36/100
# 5973/5973 [==============================] - 82s 14ms/step - loss: 0.4684 - accuracy: 0.5000 - val_loss: 0.3870 - val_accuracy: 0.8175
# Epoch 37/100
# 5973/5973 [==============================] - 80s 13ms/step - loss: 0.4380 - accuracy: 0.5000 - val_loss: 0.3784 - val_accuracy: 0.8175
# Epoch 38/100
# 5973/5973 [==============================] - 75s 13ms/step - loss: 0.4574 - accuracy: 0.5000 - val_loss: 0.3809 - val_accuracy: 0.8175
# Epoch 52/100
# 5973/5973 [==============================] - 78s 13ms/step - loss: 0.4687 - accuracy: 0.5000 - val_loss: 0.4018 - val_accuracy: 0.8175
# Epoch 56/100
# 5973/5973 [==============================] - 75s 13ms/step - loss: 0.4655 - accuracy: 0.5000 - val_loss: 0.4589 - val_accuracy: 0.8175
# Epoch 57/100
# 5973/5973 [==============================] - 80s 13ms/step - loss: 0.4447 - accuracy: 0.5000 - val_loss: 0.3891 - val_accuracy: 0.8175
# Epoch 58/100
# 5973/5973 [==============================] - 75s 13ms/step - loss: 0.5239 - accuracy: 0.5000 - val_loss: 0.3781 - val_accuracy: 0.8175
# Epoch 59/100
# 5973/5973 [==============================] - 83s 14ms/step - loss: 0.5090 - accuracy: 0.5000 - val_loss: 0.4189 - val_accuracy: 0.8175
# Epoch 65/100
# 5973/5973 [==============================] - 85s 14ms/step - loss: 0.4598 - accuracy: 0.5000 - val_loss: 0.3993 - val_accuracy: 0.8175
# Epoch 76/100
# 5973/5973 [==============================] - 80s 13ms/step - loss: 0.4657 - accuracy: 0.5000 - val_loss: 0.4053 - val_accuracy: 0.8175
# Epoch 77/100
# 5973/5973 [==============================] - 81s 14ms/step - loss: 0.4449 - accuracy: 0.5000 - val_loss: 0.3733 - val_accuracy: 0.8175
# Epoch 78/100
# 5973/5973 [==============================] - 80s 13ms/step - loss: 0.5075 - accuracy: 0.5000 - val_loss: 0.4103 - val_accuracy: 0.8175
# Epoch 79/100
# 5973/5973 [==============================] - 83s 14ms/step - loss: 0.4968 - accuracy: 0.5000 - val_loss: 0.3888 - val_accuracy: 0.8175
# Epoch 80/100
# 5973/5973 [==============================] - 85s 14ms/step - loss: 0.4763 - accuracy: 0.5000 - val_loss: 0.4122 - val_accuracy: 0.8175
# Epoch 81/100
# 5973/5973 [==============================] - 84s 14ms/step - loss: 0.4889 - accuracy: 0.5000 - val_loss: 0.4369 - val_accuracy: 0.8175
# Epoch 82/100
# 5973/5973 [==============================] - 78s 13ms/step - loss: 0.4806 - accuracy: 0.5000 - val_loss: 0.4040 - val_accuracy: 0.8175
# Epoch 83/100
# 5973/5973 [==============================] - 79s 13ms/step - loss: 0.4688 - accuracy: 0.5000 - val_loss: 0.4326 - val_accuracy: 0.8175
# Epoch 84/100
# 5973/5973 [==============================] - 76s 13ms/step - loss: 0.4917 - accuracy: 0.5000 - val_loss: 0.3996 - val_accuracy: 0.8175
# Epoch 85/100
# 5973/5973 [==============================] - 76s 13ms/step - loss: 0.4636 - accuracy: 0.5000 - val_loss: 0.4122 - val_accuracy: 0.8175
# Epoch 86/100
# 5973/5973 [==============================] - 78s 13ms/step - loss: 0.4644 - accuracy: 0.5000 - val_loss: 0.4330 - val_accuracy: 0.8175
# Epoch 87/100
# 5973/5973 [==============================] - 80s 13ms/step - loss: 0.4960 - accuracy: 0.5000 - val_loss: 0.4443 - val_accuracy: 0.8175
# Epoch 88/100
# 5973/5973 [==============================] - 84s 14ms/step - loss: 0.4467 - accuracy: 0.5000 - val_loss: 0.3838 - val_accuracy: 0.8175
# Epoch 89/100
# 5973/5973 [==============================] - 78s 13ms/step - loss: 0.4453 - accuracy: 0.5000 - val_loss: 0.3958 - val_accuracy: 0.8175
# Epoch 90/100
# 5973/5973 [==============================] - 77s 13ms/step - loss: 0.5464 - accuracy: 0.5000 - val_loss: 0.3854 - val_accuracy: 0.8175
# Epoch 91/100
# 5973/5973 [==============================] - 77s 13ms/step - loss: 0.4773 - accuracy: 0.5000 - val_loss: 0.4263 - val_accuracy: 0.8175
# Epoch 92/100
# 5973/5973 [==============================] - 81s 14ms/step - loss: 0.4731 - accuracy: 0.5000 - val_loss: 0.4199 - val_accuracy: 0.8175
# Epoch 93/100
# 5973/5973 [==============================] - 86s 14ms/step - loss: 1.0355 - accuracy: 0.5000 - val_loss: 0.4105 - val_accuracy: 0.8175
# Epoch 94/100
# 5973/5973 [==============================] - 78s 13ms/step - loss: 0.4745 - accuracy: 0.5000 - val_loss: 0.3839 - val_accuracy: 0.8175
# Epoch 95/100
# 5973/5973 [==============================] - 76s 13ms/step - loss: 0.4383 - accuracy: 0.5000 - val_loss: 0.3739 - val_accuracy: 0.8175
# Epoch 96/100
# 5973/5973 [==============================] - 79s 13ms/step - loss: 0.4872 - accuracy: 0.5000 - val_loss: 0.6847 - val_accuracy: 0.8175
# Epoch 97/100
# 5973/5973 [==============================] - 79s 13ms/step - loss: 0.4478 - accuracy: 0.5000 - val_loss: 0.3701 - val_accuracy: 0.8175
# Epoch 98/100
# 5973/5973 [==============================] - 80s 13ms/step - loss: 0.4341 - accuracy: 0.5000 - val_loss: 0.3974 - val_accuracy: 0.8175
# Epoch 99/100
# 5973/5973 [==============================] - 72s 12ms/step - loss: 0.4276 - accuracy: 0.5000 - val_loss: 0.3731 - val_accuracy: 0.8175
# Epoch 100/100
# 5973/5973 [==============================] - 72s 12ms/step - loss: 0.4638 - accuracy: 0.5000 - val_loss: 0.4105 - val_accuracy: 0.8175

# %%
import numpy as np
from sklearn.metrics import classification_report

# Train your model (already done)
#history = model.fit(train_data, train_labels_mc, epochs=100, validation_data=(val_data, val_labels_mc), verbose=1)

# Make predictions on the validation set
predictions = model.predict(val_data)

# Convert predictions to binary class labels
predicted_labels = (predictions > 0.5).astype(int).flatten()

# Generate and print the classification report
report = classification_report(val_labels_mc, predicted_labels, target_names=['Class 0', 'Class 1'])
print(report)
# Out:
# 914/914 [==============================] - 20s 22ms/step
#               precision    recall  f1-score   support
#
#      Class 0       0.00      0.00      0.00      5338
#      Class 1       0.82      1.00      0.90     23909
#
#     accuracy                           0.82     29247
#    macro avg       0.41      0.50      0.45     29247
# weighted avg       0.67      0.82      0.74     29247

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score

# Train your model (already done)
# history = model.fit(train_data, train_labels_mc, epochs=100, validation_data=(val_data, val_labels_mc), verbose=1)

# Make predictions on the validation set
predictions = model.predict(val_data)

# Convert predictions to binary class labels
predicted_labels = (predictions > 0.5).astype(int).flatten()

# Generate and print the classification report
report = classification_report(val_labels_mc, predicted_labels, target_names=['Class 0', 'Class 1'])
print("Classification Report:\n", report)

# Calculate and print the ROC AUC score
roc_auc = roc_auc_score(val_labels_mc, predictions)
print("ROC AUC Score:", roc_auc)
# Out:
# 914/914 [==============================] - 18s 18ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#      Class 0       0.00      0.00      0.00      5338
#      Class 1       0.82      1.00      0.90     23909
#
#     accuracy                           0.82     29247
#    macro avg       0.41      0.50      0.45     29247
# weighted avg       0.67      0.82      0.74     29247
#
# ROC AUC Score: 0.5
